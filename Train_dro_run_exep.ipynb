# %%
from dro_utils import *
import os
from data import *
from torchvision.models import resnet50, ResNet50_Weights
from torch import nn
from dro_train import *

# %%
reweight_groups = False
automatic_adjustment = False
use_normalized_loss = False
lr = 0.001
alpha = 0.2
batch_size = 128
weight_decay = 0
gamma = 0.1
n_epochs = 300
seed = 0
generalization_adjustment = "0"
log_every = 50
model = "resnet50"
log_dir = "./logs"
save_best = True
save_last = False
mode = 'w'
robust = False
robust_step_size = 0.01
log_every = 50
save_step = 10
save_best = True
save_last = False

# %%
if not os.path.exists(log_dir):
        os.makedirs(log_dir)
logger = Logger(os.path.join(log_dir, 'log.txt'), mode=mode)
set_seed(seed)

train_data, val_data, test_data = get_confounder_splits(
    data_dir="../datasets/waterbird", augment_data=False)

loader_kwargs = {'batch_size': batch_size, 'pin_memory': False}
train_loader = train_data.get_loader(
    train=True, reweight_groups=reweight_groups, **loader_kwargs)
val_loader = val_data.get_loader(
    train=False, reweight_groups=False, ** loader_kwargs)
test_loader = test_data.get_loader(
    train=False, reweight_groups=False, **loader_kwargs)

print(
    f'Train data: {train_data.__len__()} | Val data:  {val_data.__len__()} | Test data:  {test_data.__len__()}')

data = {}
data['train_loader'] = train_loader
data['val_loader'] = val_loader
data['test_loader'] = test_loader
data['train_data'] = train_data
data['val_data'] = val_data
data['test_data'] = test_data
n_classes = train_data.n_classes
# Out:
# Train data: 4795 | Val data:  1199 | Test data:  5794

# %%
model = resnet50(weights=ResNet50_Weights.IMAGENET1K_V2, progress=True)
model.fc = nn.Linear(in_features=model.fc.in_features, out_features=2)

logger.flush()

criterion = nn.CrossEntropyLoss(reduction='none')

train_csv_logger = CSVBatchLogger(os.path.join(
    log_dir, 'train.csv'), train_data.n_groups, mode=mode)
val_csv_logger = CSVBatchLogger(os.path.join(
    log_dir, 'val.csv'), train_data.n_groups, mode=mode)
test_csv_logger = CSVBatchLogger(os.path.join(
    log_dir, 'test.csv'), train_data.n_groups, mode=mode)

# %%
train(
    model=model,
    criterion=criterion,
    dataset=data,
    logger=logger,
    train_csv_logger=train_csv_logger,
    val_csv_logger=val_csv_logger,
    test_csv_logger=test_csv_logger,
    alpha=alpha,
    gamma=gamma,
    robust=robust,
    robust_step_size=robust_step_size,
    use_normalized_loss=use_normalized_loss,
    generalization_adjustment=generalization_adjustment,
    lr=lr,
    weight_decay=weight_decay,
    n_epochs=n_epochs,
    log_every=log_every,
    save_step=save_step,
    save_last=save_last,
    save_best=save_best,
    log_dir=log_dir,
    reweight_groups=reweight_groups,
    automatic_adjustment=automatic_adjustment)

train_csv_logger.close()
val_csv_logger.close()
test_csv_logger.close()
# Out:
# Epoch [0]:
# Training:
#   0%|          | 0/38 [00:00<?, ?it/s]
# 100%|██████████| 38/38 [00:23<00:00,  1.58it/s]
# Average incurred loss: 0.474
# Average sample loss: 0.471
# Average acc: 0.767
# [n = 3498]:	loss = 0.296  exp loss = 0.182  adjusted loss = 0.182  adv prob = 0.250000   acc = 0.976
# [n = 184]:	loss = 0.386  exp loss = 0.350  adjusted loss = 0.350  adv prob = 0.250000   acc = 0.984
# [n = 56]:	loss = 1.234  exp loss = 1.415  adjusted loss = 1.415  adv prob = 0.250000   acc = 0.000
# [n = 1057]:	loss = 1.037  exp loss = 0.987  adjusted loss = 0.987  adv prob = 0.250000   acc = 0.077
# Validation:
# 100%|██████████| 10/10 [00:04<00:00,  2.21it/s]
# Average incurred loss: 0.485
# Average sample loss: 0.472
# Average acc: 0.788
# [n = 467]:	loss = 0.164  exp loss = 0.164  adjusted loss = 0.164  adv prob = 0.250000   acc = 1.000
# [n = 466]:	loss = 0.469  exp loss = 0.481  adjusted loss = 0.481  adv prob = 0.250000   acc = 0.863
# [n = 133]:	loss = 1.454  exp loss = 1.518  adjusted loss = 1.518  adv prob = 0.250000   acc = 0.008
# [n = 133]:	loss = 0.700  exp loss = 0.779  adjusted loss = 0.779  adv prob = 0.250000   acc = 0.564
# Test:
# 100%|██████████| 46/46 [00:21<00:00,  2.12it/s]
# Average incurred loss: 0.488
# Average sample loss: 0.485
# Average acc: 0.791
# [n = 2255]:	loss = 0.166  exp loss = 0.162  adjusted loss = 0.162  adv prob = 0.250000   acc = 1.000
# [n = 2255]:	loss = 0.477  exp loss = 0.471  adjusted loss = 0.471  adv prob = 0.250000   acc = 0.863
# [n = 642]:	loss = 1.422  exp loss = 1.409  adjusted loss = 1.409  adv prob = 0.250000   acc = 0.014
# [n = 642]:	loss = 0.719  exp loss = 0.701  adjusted loss = 0.701  adv prob = 0.250000   acc = 0.578
# Current lr: 0.001000
# Current validation accuracy: 0.7881568074226379
# Best model saved at epoch 0
#
#
# Epoch [1]:
# Training:
# 100%|██████████| 38/38 [00:23<00:00,  1.64it/s]
# Average incurred loss: 0.242
# Average sample loss: 0.242
# Average acc: 0.924
# [n = 3498]:	loss = 0.123  exp loss = 0.104  adjusted loss = 0.104  adv prob = 0.250000   acc = 0.997
# [n = 184]:	loss = 0.643  exp loss = 0.682  adjusted loss = 0.682  adv prob = 0.250000   acc = 0.614
# [n = 56]:	loss = 1.538  exp loss = 1.480  adjusted loss = 1.480  adv prob = 0.250000   acc = 0.018
# [n = 1057]:	loss = 0.499  exp loss = 0.448  adjusted loss = 0.448  adv prob = 0.250000   acc = 0.782
# Validation:
# 100%|██████████| 10/10 [00:04<00:00,  2.21it/s]
# Average incurred loss: 0.514
# Average sample loss: 0.499
# Average acc: 0.719
# [n = 467]:	loss = 0.083  exp loss = 0.082  adjusted loss = 0.082  adv prob = 0.250000   acc = 0.996
# [n = 466]:	loss = 0.637  exp loss = 0.648  adjusted loss = 0.648  adv prob = 0.250000   acc = 0.590
# [n = 133]:	loss = 1.693  exp loss = 1.848  adjusted loss = 1.848  adv prob = 0.250000   acc = 0.060
# [n = 133]:	loss = 0.413  exp loss = 0.513  adjusted loss = 0.513  adv prob = 0.250000   acc = 0.857
# Test:
# 100%|██████████| 46/46 [00:21<00:00,  2.11it/s]
# Average incurred loss: 0.516
# Average sample loss: 0.513
# Average acc: 0.723
# [n = 2255]:	loss = 0.085  exp loss = 0.080  adjusted loss = 0.080  adv prob = 0.250000   acc = 0.997
# [n = 2255]:	loss = 0.648  exp loss = 0.630  adjusted loss = 0.630  adv prob = 0.250000   acc = 0.607
# [n = 642]:	loss = 1.650  exp loss = 1.633  adjusted loss = 1.633  adv prob = 0.250000   acc = 0.064
# [n = 642]:	loss = 0.438  exp loss = 0.401  adjusted loss = 0.401  adv prob = 0.250000   acc = 0.826
# Current lr: 0.001000
# Current validation accuracy: 0.7189324498176575
#
#
# Epoch [2]:
# Training:
# 100%|██████████| 38/38 [00:23<00:00,  1.64it/s]
# Average incurred loss: 0.175
# Average sample loss: 0.174
# Average acc: 0.945
# [n = 3498]:	loss = 0.071  exp loss = 0.068  adjusted loss = 0.068  adv prob = 0.250000   acc = 0.998
# [n = 184]:	loss = 0.680  exp loss = 0.666  adjusted loss = 0.666  adv prob = 0.250000   acc = 0.560
# [n = 56]:	loss = 1.689  exp loss = 1.735  adjusted loss = 1.735  adv prob = 0.250000   acc = 0.107
# [n = 1057]:	loss = 0.350  exp loss = 0.305  adjusted loss = 0.305  adv prob = 0.250000   acc = 0.879
# Validation:
# 100%|██████████| 10/10 [00:04<00:00,  2.19it/s]
# Average incurred loss: 0.523
# Average sample loss: 0.508
# Average acc: 0.715
# [n = 467]:	loss = 0.065  exp loss = 0.064  adjusted loss = 0.064  adv prob = 0.250000   acc = 0.991
# [n = 466]:	loss = 0.718  exp loss = 0.725  adjusted loss = 0.725  adv prob = 0.250000   acc = 0.552
# [n = 133]:	loss = 1.684  exp loss = 1.884  adjusted loss = 1.884  adv prob = 0.250000   acc = 0.120
# [n = 133]:	loss = 0.289  exp loss = 0.385  adjusted loss = 0.385  adv prob = 0.250000   acc = 0.910
# Test:
# 100%|██████████| 46/46 [00:22<00:00,  2.09it/s]
# Average incurred loss: 0.525
# Average sample loss: 0.522
# Average acc: 0.718
# [n = 2255]:	loss = 0.066  exp loss = 0.061  adjusted loss = 0.061  adv prob = 0.250000   acc = 0.996
# [n = 2255]:	loss = 0.729  exp loss = 0.707  adjusted loss = 0.707  adv prob = 0.250000   acc = 0.564
# [n = 642]:	loss = 1.619  exp loss = 1.600  adjusted loss = 1.600  adv prob = 0.250000   acc = 0.118
# [n = 642]:	loss = 0.324  exp loss = 0.285  adjusted loss = 0.285  adv prob = 0.250000   acc = 0.880
# Current lr: 0.001000
# Current validation accuracy: 0.714762270450592
#
#
# Epoch [3]:
# Training:
# 100%|██████████| 38/38 [00:23<00:00,  1.63it/s]
# Average incurred loss: 0.142
# Average sample loss: 0.141
# Average acc: 0.955
# [n = 3498]:	loss = 0.053  exp loss = 0.049  adjusted loss = 0.049  adv prob = 0.250000   acc = 0.998
# [n = 184]:	loss = 0.681  exp loss = 0.729  adjusted loss = 0.729  adv prob = 0.250000   acc = 0.592
# [n = 56]:	loss = 1.591  exp loss = 1.470  adjusted loss = 1.470  adv prob = 0.250000   acc = 0.179
# [n = 1057]:	loss = 0.263  exp loss = 0.223  adjusted loss = 0.223  adv prob = 0.250000   acc = 0.916
# Validation:
# 100%|██████████| 10/10 [00:04<00:00,  2.22it/s]
# Average incurred loss: 0.505
# Average sample loss: 0.489
# Average acc: 0.740
# [n = 467]:	loss = 0.051  exp loss = 0.050  adjusted loss = 0.050  adv prob = 0.250000   acc = 0.991
# [n = 466]:	loss = 0.695  exp loss = 0.700  adjusted loss = 0.700  adv prob = 0.250000   acc = 0.597
# [n = 133]:	loss = 1.702  exp loss = 1.954  adjusted loss = 1.954  adv prob = 0.250000   acc = 0.165
# [n = 133]:	loss = 0.240  exp loss = 0.336  adjusted loss = 0.336  adv prob = 0.250000   acc = 0.932
# Test:
# 100%|██████████| 46/46 [00:21<00:00,  2.11it/s]
# Average incurred loss: 0.505
# Average sample loss: 0.501
# Average acc: 0.741
# [n = 2255]:	loss = 0.051  exp loss = 0.046  adjusted loss = 0.046  adv prob = 0.250000   acc = 0.996
# [n = 2255]:	loss = 0.704  exp loss = 0.675  adjusted loss = 0.675  adv prob = 0.250000   acc = 0.607
# [n = 642]:	loss = 1.617  exp loss = 1.602  adjusted loss = 1.602  adv prob = 0.250000   acc = 0.159
# [n = 642]:	loss = 0.284  exp loss = 0.243  adjusted loss = 0.243  adv prob = 0.250000   acc = 0.894
# Current lr: 0.001000
# Current validation accuracy: 0.7397831678390503
#
#
# Epoch [4]:
# Training:
# 100%|██████████| 38/38 [00:23<00:00,  1.64it/s]
# Average incurred loss: 0.118
# Average sample loss: 0.118
# Average acc: 0.961
# [n = 3498]:	loss = 0.043  exp loss = 0.041  adjusted loss = 0.041  adv prob = 0.250000   acc = 0.999
# [n = 184]:	loss = 0.579  exp loss = 0.527  adjusted loss = 0.527  adv prob = 0.250000   acc = 0.674
# [n = 56]:	loss = 1.419  exp loss = 1.414  adjusted loss = 1.414  adv prob = 0.250000   acc = 0.250
# [n = 1057]:	loss = 0.219  exp loss = 0.190  adjusted loss = 0.190  adv prob = 0.250000   acc = 0.925
# Validation:
# 100%|██████████| 10/10 [00:04<00:00,  2.17it/s]
# Average incurred loss: 0.486
# Average sample loss: 0.470
# Average acc: 0.762
# [n = 467]:	loss = 0.044  exp loss = 0.043  adjusted loss = 0.043  adv prob = 0.250000   acc = 0.994
# [n = 466]:	loss = 0.676  exp loss = 0.684  adjusted loss = 0.684  adv prob = 0.250000   acc = 0.624
# [n = 133]:	loss = 1.655  exp loss = 1.935  adjusted loss = 1.935  adv prob = 0.250000   acc = 0.256
# [n = 133]:	loss = 0.202  exp loss = 0.294  adjusted loss = 0.294  adv prob = 0.250000   acc = 0.940
# Test:
# 100%|██████████| 46/46 [00:22<00:00,  2.08it/s]
# Average incurred loss: 0.482
# Average sample loss: 0.479
# Average acc: 0.759
# [n = 2255]:	loss = 0.044  exp loss = 0.039  adjusted loss = 0.039  adv prob = 0.250000   acc = 0.996
# [n = 2255]:	loss = 0.681  exp loss = 0.646  adjusted loss = 0.646  adv prob = 0.250000   acc = 0.634
# [n = 642]:	loss = 1.546  exp loss = 1.531  adjusted loss = 1.531  adv prob = 0.250000   acc = 0.220
# [n = 642]:	loss = 0.254  exp loss = 0.213  adjusted loss = 0.213  adv prob = 0.250000   acc = 0.903
# Current lr: 0.001000
# Current validation accuracy: 0.7623019218444824
#
#
# Epoch [5]:
# Training:
# 100%|██████████| 38/38 [00:23<00:00,  1.64it/s]
# Average incurred loss: 0.099
# Average sample loss: 0.099
# Average acc: 0.969
# [n = 3498]:	loss = 0.035  exp loss = 0.032  adjusted loss = 0.032  adv prob = 0.250000   acc = 0.999
# [n = 184]:	loss = 0.479  exp loss = 0.434  adjusted loss = 0.434  adv prob = 0.250000   acc = 0.766
# [n = 56]:	loss = 1.268  exp loss = 1.136  adjusted loss = 1.136  adv prob = 0.250000   acc = 0.375
# [n = 1057]:	loss = 0.183  exp loss = 0.178  adjusted loss = 0.178  adv prob = 0.250000   acc = 0.939
# Validation:
# 100%|██████████| 10/10 [00:04<00:00,  2.18it/s]
# Average incurred loss: 0.462
# Average sample loss: 0.445
# Average acc: 0.786
# [n = 467]:	loss = 0.037  exp loss = 0.035  adjusted loss = 0.035  adv prob = 0.250000   acc = 0.994
# [n = 466]:	loss = 0.625  exp loss = 0.636  adjusted loss = 0.636  adv prob = 0.250000   acc = 0.674
# [n = 133]:	loss = 1.658  exp loss = 1.976  adjusted loss = 1.976  adv prob = 0.250000   acc = 0.301
# [n = 133]:	loss = 0.188  exp loss = 0.279  adjusted loss = 0.279  adv prob = 0.250000   acc = 0.940
# Test:
# 100%|██████████| 46/46 [00:22<00:00,  2.08it/s]
# Average incurred loss: 0.454
# Average sample loss: 0.451
# Average acc: 0.784
# [n = 2255]:	loss = 0.037  exp loss = 0.032  adjusted loss = 0.032  adv prob = 0.250000   acc = 0.996
# [n = 2255]:	loss = 0.626  exp loss = 0.592  adjusted loss = 0.592  adv prob = 0.250000   acc = 0.682
# [n = 642]:	loss = 1.522  exp loss = 1.509  adjusted loss = 1.509  adv prob = 0.250000   acc = 0.269
# [n = 642]:	loss = 0.246  exp loss = 0.203  adjusted loss = 0.203  adv prob = 0.250000   acc = 0.905
# Current lr: 0.001000
# Current validation accuracy: 0.7864887714385986
#
#
# Epoch [6]:
# Training:
# 100%|██████████| 38/38 [00:23<00:00,  1.64it/s]
# Average incurred loss: 0.084
# Average sample loss: 0.085
# Average acc: 0.975
# [n = 3498]:	loss = 0.030  exp loss = 0.032  adjusted loss = 0.032  adv prob = 0.250000   acc = 0.999
# [n = 184]:	loss = 0.412  exp loss = 0.465  adjusted loss = 0.465  adv prob = 0.250000   acc = 0.810
# [n = 56]:	loss = 1.101  exp loss = 1.181  adjusted loss = 1.181  adv prob = 0.250000   acc = 0.411
# [n = 1057]:	loss = 0.152  exp loss = 0.156  adjusted loss = 0.156  adv prob = 0.250000   acc = 0.954
# Validation:
# 100%|██████████| 10/10 [00:04<00:00,  2.21it/s]
# Average incurred loss: 0.458
# Average sample loss: 0.442
# Average acc: 0.792
# [n = 467]:	loss = 0.037  exp loss = 0.035  adjusted loss = 0.035  adv prob = 0.250000   acc = 0.994
# [n = 466]:	loss = 0.657  exp loss = 0.663  adjusted loss = 0.663  adv prob = 0.250000   acc = 0.667
# [n = 133]:	loss = 1.544  exp loss = 1.863  adjusted loss = 1.863  adv prob = 0.250000   acc = 0.368
# [n = 133]:	loss = 0.158  exp loss = 0.240  adjusted loss = 0.240  adv prob = 0.250000   acc = 0.947
# Test:
# 100%|██████████| 46/46 [00:21<00:00,  2.10it/s]
# Average incurred loss: 0.449
# Average sample loss: 0.446
# Average acc: 0.788
# [n = 2255]:	loss = 0.036  exp loss = 0.031  adjusted loss = 0.031  adv prob = 0.250000   acc = 0.996
# [n = 2255]:	loss = 0.656  exp loss = 0.620  adjusted loss = 0.620  adv prob = 0.250000   acc = 0.674
# [n = 642]:	loss = 1.400  exp loss = 1.389  adjusted loss = 1.389  adv prob = 0.250000   acc = 0.341
# [n = 642]:	loss = 0.217  exp loss = 0.176  adjusted loss = 0.176  adv prob = 0.250000   acc = 0.911
# Current lr: 0.001000
# Current validation accuracy: 0.7923269271850586
# Best model saved at epoch 6
#
#
# Epoch [7]:
# Training:
# 100%|██████████| 38/38 [00:23<00:00,  1.64it/s]
# Average incurred loss: 0.071
# Average sample loss: 0.072
# Average acc: 0.980
# [n = 3498]:	loss = 0.026  exp loss = 0.026  adjusted loss = 0.026  adv prob = 0.250000   acc = 0.999
# [n = 184]:	loss = 0.338  exp loss = 0.323  adjusted loss = 0.323  adv prob = 0.250000   acc = 0.864
# [n = 56]:	loss = 0.932  exp loss = 1.024  adjusted loss = 1.024  adv prob = 0.250000   acc = 0.482
# [n = 1057]:	loss = 0.128  exp loss = 0.128  adjusted loss = 0.128  adv prob = 0.250000   acc = 0.963
# Validation:
# 100%|██████████| 10/10 [00:04<00:00,  2.16it/s]
# Average incurred loss: 0.447
# Average sample loss: 0.431
# Average acc: 0.796
# [n = 467]:	loss = 0.032  exp loss = 0.030  adjusted loss = 0.030  adv prob = 0.250000   acc = 0.994
# [n = 466]:	loss = 0.633  exp loss = 0.643  adjusted loss = 0.643  adv prob = 0.250000   acc = 0.678
# [n = 133]:	loss = 1.549  exp loss = 1.890  adjusted loss = 1.890  adv prob = 0.250000   acc = 0.368
# [n = 133]:	loss = 0.153  exp loss = 0.238  adjusted loss = 0.238  adv prob = 0.250000   acc = 0.947
# Test:
# 100%|██████████| 46/46 [00:22<00:00,  2.08it/s]
# Average incurred loss: 0.434
# Average sample loss: 0.431
# Average acc: 0.803
# [n = 2255]:	loss = 0.032  exp loss = 0.027  adjusted loss = 0.027  adv prob = 0.250000   acc = 0.996
# [n = 2255]:	loss = 0.627  exp loss = 0.590  adjusted loss = 0.590  adv prob = 0.250000   acc = 0.696
# [n = 642]:	loss = 1.387  exp loss = 1.381  adjusted loss = 1.381  adv prob = 0.250000   acc = 0.391
# [n = 642]:	loss = 0.216  exp loss = 0.175  adjusted loss = 0.175  adv prob = 0.250000   acc = 0.916
# Current lr: 0.001000
# Current validation accuracy: 0.796497106552124
# Best model saved at epoch 7
#
#
# Epoch [8]:
# Training:
# 100%|██████████| 38/38 [00:23<00:00,  1.63it/s]
# Average incurred loss: 0.063
# Average sample loss: 0.063
# Average acc: 0.983
# [n = 3498]:	loss = 0.023  exp loss = 0.022  adjusted loss = 0.022  adv prob = 0.250000   acc = 0.999
# [n = 184]:	loss = 0.310  exp loss = 0.385  adjusted loss = 0.385  adv prob = 0.250000   acc = 0.880
# [n = 56]:	loss = 0.833  exp loss = 0.700  adjusted loss = 0.700  adv prob = 0.250000   acc = 0.625
# [n = 1057]:	loss = 0.111  exp loss = 0.095  adjusted loss = 0.095  adv prob = 0.250000   acc = 0.966
# Validation:
# 100%|██████████| 10/10 [00:04<00:00,  2.18it/s]
# Average incurred loss: 0.444
# Average sample loss: 0.427
# Average acc: 0.803
# [n = 467]:	loss = 0.032  exp loss = 0.030  adjusted loss = 0.030  adv prob = 0.250000   acc = 0.994
# [n = 466]:	loss = 0.645  exp loss = 0.653  adjusted loss = 0.653  adv prob = 0.250000   acc = 0.678
# [n = 133]:	loss = 1.488  exp loss = 1.829  adjusted loss = 1.829  adv prob = 0.250000   acc = 0.429
# [n = 133]:	loss = 0.139  exp loss = 0.216  adjusted loss = 0.216  adv prob = 0.250000   acc = 0.947
# Test:
# 100%|██████████| 46/46 [00:22<00:00,  2.08it/s]
# Average incurred loss: 0.428
# Average sample loss: 0.425
# Average acc: 0.813
# [n = 2255]:	loss = 0.032  exp loss = 0.027  adjusted loss = 0.027  adv prob = 0.250000   acc = 0.996
# [n = 2255]:	loss = 0.637  exp loss = 0.600  adjusted loss = 0.600  adv prob = 0.250000   acc = 0.703
# [n = 642]:	loss = 1.313  exp loss = 1.311  adjusted loss = 1.311  adv prob = 0.250000   acc = 0.449
# [n = 642]:	loss = 0.205  exp loss = 0.165  adjusted loss = 0.165  adv prob = 0.250000   acc = 0.921
# Current lr: 0.001000
# Current validation accuracy: 0.8031693696975708
# Best model saved at epoch 8
#
#
# Epoch [9]:
# Training:
# 100%|██████████| 38/38 [00:23<00:00,  1.63it/s]
# Average incurred loss: 0.054
# Average sample loss: 0.054
# Average acc: 0.986
# [n = 3498]:	loss = 0.020  exp loss = 0.021  adjusted loss = 0.021  adv prob = 0.250000   acc = 0.999
# [n = 184]:	loss = 0.255  exp loss = 0.293  adjusted loss = 0.293  adv prob = 0.250000   acc = 0.918
# [n = 56]:	loss = 0.752  exp loss = 0.694  adjusted loss = 0.694  adv prob = 0.250000   acc = 0.607
# [n = 1057]:	loss = 0.093  exp loss = 0.094  adjusted loss = 0.094  adv prob = 0.250000   acc = 0.973
# Validation:
# 100%|██████████| 10/10 [00:04<00:00,  2.19it/s]
# Average incurred loss: 0.435
# Average sample loss: 0.418
# Average acc: 0.810
# [n = 467]:	loss = 0.029  exp loss = 0.026  adjusted loss = 0.026  adv prob = 0.250000   acc = 0.994
# [n = 466]:	loss = 0.625  exp loss = 0.633  adjusted loss = 0.633  adv prob = 0.250000   acc = 0.695
# [n = 133]:	loss = 1.490  exp loss = 1.845  adjusted loss = 1.845  adv prob = 0.250000   acc = 0.429
# [n = 133]:	loss = 0.138  exp loss = 0.219  adjusted loss = 0.219  adv prob = 0.250000   acc = 0.947
# Test:
# 100%|██████████| 46/46 [00:22<00:00,  2.09it/s]
# Average incurred loss: 0.418
# Average sample loss: 0.415
# Average acc: 0.822
# [n = 2255]:	loss = 0.028  exp loss = 0.024  adjusted loss = 0.024  adv prob = 0.250000   acc = 0.996
# [n = 2255]:	loss = 0.614  exp loss = 0.575  adjusted loss = 0.575  adv prob = 0.250000   acc = 0.722
# [n = 642]:	loss = 1.307  exp loss = 1.300  adjusted loss = 1.300  adv prob = 0.250000   acc = 0.469
# [n = 642]:	loss = 0.206  exp loss = 0.165  adjusted loss = 0.165  adv prob = 0.250000   acc = 0.921
# Current lr: 0.001000
# Current validation accuracy: 0.8098416328430176
# Best model saved at epoch 9
